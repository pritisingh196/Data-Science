# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 15])
ypoints = np.array([0, 300])

plt.plot(xpoints, ypoints)
plt.show()

# %%
#second example

import matplotlib.pyplot as plt
import numpy as np

apoints = np.array([0, 20])
bpoints = np.array([0, 400])

plt.plot(apoints, bpoints)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10.20,30,40,50,60,70]
plt.plot(x)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50,60,70]
y=[10,20,30,40,50,60,70]
plt.plot(x ,y)
plt.show()
