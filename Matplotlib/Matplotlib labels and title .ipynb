# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("win score")
plt.ylabel("win team")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Data")
plt.xlabel("win team")
plt.ylabel("win score")

plt.show()

# %%
#set font properties for title and labels
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'green','size':20}
font2 = {'family':'serif','color':'red','size':15}

plt.title("Sports  Data", fontdict = font1)
plt.xlabel("win team", fontdict = font2)
plt.ylabel("win score", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
#set font properties for title and labels position
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports  Data",loc='left')
plt.xlabel("win team")
plt.ylabel("win score")

plt.plot(x, y)
plt.show()

# %%
#set font properties for title and labels position
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports  Data",loc='right')
plt.xlabel("win team")
plt.ylabel("win score")

plt.plot(x, y)
plt.show()

# %%
#set font properties for title and labels position
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports  Data",loc='center')
plt.xlabel("win team")
plt.ylabel("win score")

plt.plot(x, y)
plt.show()
