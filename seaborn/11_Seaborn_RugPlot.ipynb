# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as sts

# %%
# **2. Import the supermart data excel file**
mart = pd.read_excel("/content/supermarket_sales.xlsx")
pd.set_option('display.max_rows',None)
mart.head(10)
# Out:
#     Invoice ID Branch      City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Mandalay        Member  Female      Food_and_beverages
# 1  351-62-0822      B  Mandalay        Member  Female     Fashion_accessories
# 2  529-56-3974      B  Mandalay        Member    Male  Electronic_accessories
# 3  299-46-1805      B  Mandalay        Member  Female       Sports_and_travel
# 4  319-50-3348      B  Mandalay        Normal  Female      Home_and_lifestyle
# 5  371-85-5789      B  Mandalay        Normal    Male       Health_and_beauty
# 6  273-16-6619      B  Mandalay        Normal    Male      Home_and_lifestyle
# 7  649-29-6775      B  Mandalay        Normal    Male     Fashion_accessories
# 8  145-94-9061      B  Mandalay        Normal  Female      Food_and_beverages
# 9  871-79-8483      B  Mandalay        Normal    Male     Fashion_accessories
#
#    Unit price  Quantity   Tax 5%     Total                 Date      Time  \
# 0       54.84         3   8.2260  172.7460            2/20/2019  13:27:00
# 1       14.48         4   2.8960   60.8160  2019-06-02 00:00:00  18:07:00
# 2       25.51         4   5.1020  107.1420  2019-09-03 00:00:00  17:03:00
# 3       93.72         6  28.1160  590.4360            1/15/2019  16:19:00
# 4       40.30         2   4.0300   84.6300  2019-11-03 00:00:00  15:30:00
# 5       87.98         3  13.1970  277.1370  2019-05-03 00:00:00  10:40:00
# 6       33.20         2   3.3200   69.7200            3/15/2019  12:20:00
# 7       33.52         1   1.6760   35.1960  2019-08-02 00:00:00  15:31:00
# 8       88.36         5  22.0900  463.8900            1/25/2019  19:48:00
# 9       94.13         5  23.5325  494.1825            2/25/2019  19:39:00
#
#        Payment    cogs  gross margin percentage  gross income  Rating
# 0  Credit card  164.52                 4.761905        8.2260     5.9
# 1      Ewallet   57.92                 4.761905        2.8960     4.5
# 2         Cash  102.04                 4.761905        5.1020     6.8
# 3         Cash  562.32                 4.761905       28.1160     4.5
# 4      Ewallet   80.60                 4.761905        4.0300     4.4
# 5      Ewallet  263.94                 4.761905       13.1970     5.1
# 6  Credit card   66.40                 4.761905        3.3200     4.4
# 7         Cash   33.52                 4.761905        1.6760     6.7
# 8         Cash  441.80                 4.761905       22.0900     9.6
# 9  Credit card  470.65                 4.761905       23.5325     4.8
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_23['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_24['Unit price'].plot(kind='hist', bins=20, title='Unit price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_25['Quantity'].plot(kind='hist', bins=20, title='Quantity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_26['Tax 5%'].plot(kind='hist', bins=20, title='Tax 5%')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_27.groupby('Customer type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_28.groupby('Gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_29.groupby('Product line').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_30.groupby('Payment').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_31.plot(kind='scatter', x='index', y='Unit price', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_32.plot(kind='scatter', x='Unit price', y='Quantity', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_33.plot(kind='scatter', x='Quantity', y='Tax 5%', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_34.plot(kind='scatter', x='Tax 5%', y='Total', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Unit price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_35.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Customer type')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Customer type', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Unit price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Unit price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_36.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Gender')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Gender', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Unit price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Unit price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_37.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Product line')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Product line', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Unit price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Unit price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_38.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Payment')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Payment', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Unit price')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_39['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_40['Unit price'].plot(kind='line', figsize=(8, 4), title='Unit price')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_41['Quantity'].plot(kind='line', figsize=(8, 4), title='Quantity')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_42['Tax 5%'].plot(kind='line', figsize=(8, 4), title='Tax 5%')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Gender'].value_counts()
#     for x_label, grp in _df_43.groupby('Customer type')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Customer type')
# _ = plt.ylabel('Gender')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Product line'].value_counts()
#     for x_label, grp in _df_44.groupby('Gender')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Gender')
# _ = plt.ylabel('Product line')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Payment'].value_counts()
#     for x_label, grp in _df_45.groupby('Product line')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Product line')
# _ = plt.ylabel('Payment')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_46['Customer type'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_46, x='index', y='Customer type', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_47['Gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_47, x='index', y='Gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_48['Product line'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_48, x='index', y='Product line', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_49['Payment'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_49, x='index', y='Payment', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
# Create a basic RUG plot for one variable
plt.figure(figsize=(15,5))
sns.rugplot(data=mart, x='Unit price')
# Out:
# <Axes: xlabel='Unit price'>

# %%
# Create a RUG plot for two variables
plt.figure(figsize=(15,5))
sns.rugplot(data=mart, x='Unit price',y='gross income')
# Out:
# <Axes: xlabel='Unit price', ylabel='gross income'>

# %%
#  Group it by a categorical variable using hue
plt.figure(figsize=(15,5))
sns.rugplot(data=mart, x='Unit price',y='gross income',hue='Gender')
# Out:
# <Axes: xlabel='Unit price', ylabel='gross income'>

# %%
# Change the height of Rugs in the RUG Plot
plt.figure(figsize=(15,5))
sns.rugplot(data=mart, x='Unit price',y='gross income',hue='Gender',height=0.05)
# Out:
# <Axes: xlabel='Unit price', ylabel='gross income'>

# %%
# Combine this with a KDE Plot
plt.figure(figsize=(15,5))
sns.kdeplot(data=mart, x='Unit price',y='gross income',hue='Gender',fill=True)
sns.rugplot(data=mart, x='Unit price',y='gross income',hue='Gender')
# Out:
# <Axes: xlabel='Unit price', ylabel='gross income'>

# %%
# Combine this with a SCATTER PLOT
# plt.figure(figsize=(15,5))
sns.scatterplot(data=mart, x='Unit price',y='gross income',hue='Gender')
sns.rugplot(data=mart, x='Unit price',y='gross income',hue='Gender')
# Out:
# <Axes: xlabel='Unit price', ylabel='gross income'>

# %%
# Show Rugs outside of the Axis
plt.figure(figsize=(15,5))
sns.kdeplot(data=mart, x='Unit price',y='gross income',hue='Gender',fill=True)
sns.rugplot(data=mart, x='Unit price',y='gross income',hue='Gender',height=-0.01,clip_on=False)
# Out:
# <Axes: xlabel='Unit price', ylabel='gross income'>
