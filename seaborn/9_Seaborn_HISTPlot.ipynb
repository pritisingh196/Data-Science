# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# **2. Import the supermart data excel file**
mart = pd.read_excel("/content/supermarket_sales.xlsx")
mart.head()
# Out:
#     Invoice ID Branch      City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Mandalay        Member  Female      Food_and_beverages
# 1  351-62-0822      B  Mandalay        Member  Female     Fashion_accessories
# 2  529-56-3974      B  Mandalay        Member    Male  Electronic_accessories
# 3  299-46-1805      B  Mandalay        Member  Female       Sports_and_travel
# 4  319-50-3348      B  Mandalay        Normal  Female      Home_and_lifestyle
#
#    Unit price  Quantity  Tax 5%    Total                 Date      Time  \
# 0       54.84         3   8.226  172.746            2/20/2019  13:27:00
# 1       14.48         4   2.896   60.816  2019-06-02 00:00:00  18:07:00
# 2       25.51         4   5.102  107.142  2019-09-03 00:00:00  17:03:00
# 3       93.72         6  28.116  590.436            1/15/2019  16:19:00
# 4       40.30         2   4.030   84.630  2019-11-03 00:00:00  15:30:00
#
#        Payment    cogs  gross margin percentage  gross income  Rating
# 0  Credit card  164.52                 4.761905         8.226     5.9
# 1      Ewallet   57.92                 4.761905         2.896     4.5
# 2         Cash  102.04                 4.761905         5.102     6.8
# 3         Cash  562.32                 4.761905        28.116     4.5
# 4      Ewallet   80.60                 4.761905         4.030     4.4

# %%
pd.set_option('display.max_rows',None)

# %%
mart = pd.read_excel(r"/content/supermarket_sales.xlsx")
mart = mart[['Gender','Payment','Unit price','Quantity','Total','gross income']]
mart.head(10)
# Out:
#    Gender      Payment  Unit price  Quantity     Total  gross income
# 0  Female  Credit card       54.84         3  172.7460        8.2260
# 1  Female      Ewallet       14.48         4   60.8160        2.8960
# 2    Male         Cash       25.51         4  107.1420        5.1020
# 3  Female         Cash       93.72         6  590.4360       28.1160
# 4  Female      Ewallet       40.30         2   84.6300        4.0300
# 5    Male      Ewallet       87.98         3  277.1370       13.1970
# 6    Male  Credit card       33.20         2   69.7200        3.3200
# 7    Male         Cash       33.52         1   35.1960        1.6760
# 8  Female         Cash       88.36         5  463.8900       22.0900
# 9    Male  Credit card       94.13         5  494.1825       23.5325
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Unit price'].plot(kind='hist', bins=20, title='Unit price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Quantity'].plot(kind='hist', bins=20, title='Quantity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Total'].plot(kind='hist', bins=20, title='Total')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('Gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('Payment').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='index', y='Unit price', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='Unit price', y='Quantity', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='Quantity', y='Total', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='Total', y='gross income', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Unit price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Gender')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Gender', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Unit price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Unit price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Payment')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Payment', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Unit price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Quantity']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Gender')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Gender', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Quantity')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Quantity']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_13.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Payment')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Payment', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Quantity')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_14['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['Unit price'].plot(kind='line', figsize=(8, 4), title='Unit price')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['Quantity'].plot(kind='line', figsize=(8, 4), title='Quantity')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['Total'].plot(kind='line', figsize=(8, 4), title='Total')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Payment'].value_counts()
#     for x_label, grp in _df_18.groupby('Gender')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Gender')
# _ = plt.ylabel('Payment')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_19['Gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_19, x='index', y='Gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_20['Payment'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_20, x='index', y='Payment', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_21['Gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_21, x='Unit price', y='Gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_22['Payment'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_22, x='Unit price', y='Payment', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
# **1. Create a basic HISTOGRAM on X or Y axis**
sns.histplot(data=mart,y='Total')
# Out:
# <Axes: xlabel='Count', ylabel='Total'>

# %%
# **Change the Bins Width using binwidth arguement**
sns.histplot(data=mart,x='Total',binwidth=150)
# Out:
# <Axes: xlabel='Total', ylabel='Count'>

# %%
# **. Change Number of Bins and Interval**
plt.figure(figsize=(15,5))
sns.histplot(data=mart,x='Total',bins=np.arange(0,1100,50))
plt.xticks(np.arange(0,1100,50))
# Out:
# ([<matplotlib.axis.XTick at 0x78e37a6f53f0>,
#   <matplotlib.axis.XTick at 0x78e37a6f5390>,
#   <matplotlib.axis.XTick at 0x78e37a6f69b0>,
#   <matplotlib.axis.XTick at 0x78e37a755bd0>,
#   <matplotlib.axis.XTick at 0x78e37a756680>,
#   <matplotlib.axis.XTick at 0x78e37a757130>,
#   <matplotlib.axis.XTick at 0x78e37a757be0>,
#   <matplotlib.axis.XTick at 0x78e37a755f30>,
#   <matplotlib.axis.XTick at 0x78e37a755720>,
#   <matplotlib.axis.XTick at 0x78e37a726440>,
#   <matplotlib.axis.XTick at 0x78e37a725f00>,
#   <matplotlib.axis.XTick at 0x78e37a725ed0>,
#   <matplotlib.axis.XTick at 0x78e37a57e6e0>,
#   <matplotlib.axis.XTick at 0x78e37a59d4b0>,
#   <matplotlib.axis.XTick at 0x78e37a59df60>,
#   <matplotlib.axis.XTick at 0x78e37a59ea10>,
#   <matplotlib.axis.XTick at 0x78e37a59e1a0>,
#   <matplotlib.axis.XTick at 0x78e37a59f310>,
#   <matplotlib.axis.XTick at 0x78e37a59fdc0>,
#   <matplotlib.axis.XTick at 0x78e37a5b48b0>,
#   <matplotlib.axis.XTick at 0x78e37a5b5360>,
#   <matplotlib.axis.XTick at 0x78e37a59d720>],
#  [Text(0, 0, '0'),
#   Text(50, 0, '50'),
#   Text(100, 0, '100'),
#   Text(150, 0, '150'),
#   Text(200, 0, '200'),
#   Text(250, 0, '250'),
#   Text(300, 0, '300'),
#   Text(350, 0, '350'),
#   Text(400, 0, '400'),
#   Text(450, 0, '450'),
#   Text(500, 0, '500'),
#   Text(550, 0, '550'),
#   Text(600, 0, '600'),
#   Text(650, 0, '650'),
#   Text(700, 0, '700'),
#   Text(750, 0, '750'),
#   Text(800, 0, '800'),
#   Text(850, 0, '850'),
#   Text(900, 0, '900'),
#   Text(950, 0, '950'),
#   Text(1000, 0, '1000'),
#   Text(1050, 0, '1050')])

# %%
# ** Combine with KDE**
sns.histplot(data=mart,x='Total',kde=True)
# Out:
# <Axes: xlabel='Total', ylabel='Count'>

# %%
# ** Use a categorical variable in HUE and STACK it using MULTIPLE agruement**
sns.histplot(data=mart,x='Total',hue='Payment',multiple='stack')
# Out:
# <Axes: xlabel='Total', ylabel='Count'>

# %%
# ** Make it a step/poly plot using ELEMENT arguement and change the FILL**
sns.histplot(data=mart,x='Total',hue='Payment',element='poly')
# Out:
# <Axes: xlabel='Total', ylabel='Count'>

# %%
# ** Use categorical variable and shrink it**
sns.histplot(data=mart,x='Total',stat='probability')
# Out:
# <Axes: xlabel='Total', ylabel='Probability'>

# %%
# ** Create a Bivariate Histogram**
sns.histplot(data=mart,x='Total',y='gross income')
# Out:
# <Axes: xlabel='Total', ylabel='gross income'>
