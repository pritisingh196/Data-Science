# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as sts

# %%
mart = pd.read_csv(r'/content/train.csv').sample(50)

# %%
# Create a basic SCATTER PLOT
sns.scatterplot(data=mart)
# Out:
# <Axes: >
