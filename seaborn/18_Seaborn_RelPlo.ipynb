# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as sts

# %%
mart = pd.read_excel(r'/content/supermarket_sales.xlsx').sample(n=50)
mart.columns=mart.columns.str.lower()
mart.head()
# Out:
#       invoice id branch       city customer type  gender  \
# 413  746-68-6593      C  Naypyitaw        Member  Female
# 260  457-94-0464      B   Mandalay        Member    Male
# 372  861-77-0145      C  Naypyitaw        Member    Male
# 786  612-36-5536      A     Yangon        Member    Male
# 666  365-64-0515      A     Yangon        Normal  Female
#
#                product line  unit price  quantity   tax 5%     total  \
# 413       Sports_and_travel       87.16         2   8.7160  183.0360
# 260  Electronic_accessories       87.87         9  39.5415  830.3715
# 372  Electronic_accessories       81.97        10  40.9850  860.6850
# 786      Food_and_beverages       80.96         8  32.3840  680.0640
# 666  Electronic_accessories       46.95         5  11.7375  246.4875
#
#                     date      time      payment    cogs  \
# 413  2019-11-01 00:00:00  14:29:00  Credit card  174.32
# 260            1/31/2019  20:32:00      Ewallet  790.83
# ...

# %%
sns.relplot(data=mart,
 palette=['green', 'red', 'yellow'])
# Out:
# <ipython-input-78-14d1632e6351>:1: UserWarning:
# The palette list has fewer values (3) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   sns.relplot(data=mart,
