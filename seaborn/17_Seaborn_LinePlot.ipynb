# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as sts

# %%
mart = pd.read_csv(r'/content/train.csv').sample(50)

# %%
mart.head()
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 868          869         0       3    van Melkebeke, Mr. Philemon    male
# 592          593         0       3     Elsbury, Mr. William James    male
# 474          475         0       3    Strandberg, Miss. Ida Sofia  female
# 883          884         0       2  Banfield, Mr. Frederick James    male
# 833          834         0       3         Augustsson, Mr. Albert    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 868   NaN      0      0            345777   9.5000   NaN        S
# 592  47.0      0      0          A/5 3902   7.2500   NaN        S
# 474  22.0      0      0              7553   9.8375   NaN        S
# 883  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 833  23.0      0      0            347468   7.8542   NaN        S
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_80['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_81['PassengerId'].plot(kind='hist', bins=20, title='PassengerId')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_82['Pclass'].plot(kind='hist', bins=20, title='Pclass')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_83['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_84.groupby('Name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_85.groupby('Sex').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_86.groupby('Ticket').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_87.plot(kind='scatter', x='index', y='PassengerId', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_88.plot(kind='scatter', x='PassengerId', y='Pclass', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_89.plot(kind='scatter', x='Pclass', y='Age', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_90.plot(kind='scatter', x='Age', y='Fare', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Survived']
#   ys = series['index']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_91.sort_values('Survived', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Name')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Name', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Survived')
# _ = plt.ylabel('index')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Survived']
#   ys = series['index']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_92.sort_values('Survived', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Sex')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Sex', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Survived')
# _ = plt.ylabel('index')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Survived']
#   ys = series['index']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_93.sort_values('Survived', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Ticket')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Ticket', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Survived')
# _ = plt.ylabel('index')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Survived']
#   ys = series['PassengerId']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_94.sort_values('Survived', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Name')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Name', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Survived')
# _ = plt.ylabel('PassengerId')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_95['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_96['PassengerId'].plot(kind='line', figsize=(8, 4), title='PassengerId')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_97['Pclass'].plot(kind='line', figsize=(8, 4), title='Pclass')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_98['Age'].plot(kind='line', figsize=(8, 4), title='Age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Sex'].value_counts()
#     for x_label, grp in _df_99.groupby('Name')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Name')
# _ = plt.ylabel('Sex')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Ticket'].value_counts()
#     for x_label, grp in _df_100.groupby('Sex')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Sex')
# _ = plt.ylabel('Ticket')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_101['Name'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_101, x='index', y='Name', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_102['Sex'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_102, x='index', y='Sex', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_103['Ticket'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_103, x='index', y='Ticket', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_104['Name'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_104, x='PassengerId', y='Name', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
height = [5, 6, 7, 6.5,4]
age    = [22,25,30,25,25]
sns.lineplot(x=age,y=height,estimator=sum)
# Out:
# <Axes: >
